# %% [markdown]
# ## generate Q/A in general for all files

# %%
import os
import json
import time
from pathlib import Path
from dotenv import load_dotenv
from groq import Groq


# ============================================
#  FUNCTION TO GENERATE Q&A PAIRS VIA GROQ
# ============================================
def GenerationGroq(search_results, groq_key, add_info="", temperature=0.7, max_tokens=8192):
    """
    Generate question–answer pairs about ENSA Tétouan from a document using Groq GPT-OSS-20B.
    """
    client = Groq(api_key=groq_key)

    prompt = f"""
    You are an assistant generating realistic question–answer pairs for a chatbot about ENSA Tétouan.

    Context document:
    {search_results}

    Your goal:
    - Generate between 5 and 10 diverse and relevant question–answer pairs.
    - Each question should be written naturally as if from a student.
    - Answers must be factual, in French, concise and helpful.
    - {add_info}

    Output format:
    Each line must be a valid JSON object (JSONL) like:
    {{"instruction": "student question", "input": "", "output": "assistant answer"}}

    Important:
    - Do NOT include explanations, markdown, or extra text.
    - Return only valid JSONL lines.
    """

    # === Stream completion ===
    completion = client.chat.completions.create(
        model="openai/gpt-oss-20b",
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature,
        max_completion_tokens=max_tokens,
        top_p=1,
        reasoning_effort="medium",
        stream=True
    )

    # === Collect streamed content ===
    generations = ""
    for chunk in completion:
        content_piece = chunk.choices[0].delta.content or ""
        print(content_piece, end="")  # live feedback
        generations += content_piece

    return generations.strip()

# %%
from pathlib import Path
import os

current_path = Path.cwd()

target_file = current_path.parents[0]
print(target_file)

base_path = target_file / "data" / "data_final"
print(base_path)
# Out:
# c:\Users\PC Paradise\Desktop\Work\Projects\ENSATe-chatbot
# c:\Users\PC Paradise\Desktop\Work\Projects\ENSATe-chatbot\data\data_final

# %%
from dotenv import load_dotenv 

load_dotenv()
GROQ_KEY = os.getenv("groq_api")
add_info = ""
# === Main Loop ===
all_pairs = []

for folder in os.listdir(base_path):
    folder_path = base_path / folder
    if not folder_path.is_dir():
        continue

    for file in os.listdir(folder_path):
        path = folder_path / file

        if not path.is_file():
            continue

        try:
            # Handle both JSON and TXT files
            if path.suffix == ".json":
                with open(path, "r", encoding="utf-8") as f:
                    content = json.load(f)
            else:
                with open(path, "r", encoding="utf-8") as f:
                    content = f.read()

            # Call your model/generation function
            print(f"generating for : {path.name}")
            result = GenerationGroq("", content, GROQ_KEY, add_info)

            # Parse generated JSON lines safely
            for line in result.splitlines():
                try:
                    pair = json.loads(line)
                    all_pairs.append(pair)
                except json.JSONDecodeError:
                    continue

        except Exception as e:
            print(f"Error reading {path.name}: {e}")
            continue

print(f"Total pairs collected: {len(all_pairs)}")
# Out:
# generating for : calendrier-printemps-2025
# generating for : les clubs de lecole.txt
# generating for : commission Culturelle et Activités Sportive issue du Conseil d’établissement.txt
# generating for : Commission de coordination et de suivi du budget issue du conseil d’établissement.txt
# generating for : Commission de Recherche Scientifique et Coopération issue du Conseil d’Établissement.txt
# generating for : commission pédagogique issue du Conseil d’Établissement.txt
# generating for : Commission.txt
# generating for : Membres Conseil Etablissement.txt
# generating for : departement-genie-informatique.txt
# generating for : departement-humanites.txt
# generating for : departement-ingenierie-et-technologie-des-systemes-industriels-itsi.txt
# generating for : departement-intelligence-artificielle-et-digitalisation-iad.txt
# generating for : departement-sciences-et-technologies-industrielles-et-civiles-stic.txt
# generating for : departement-sciences-mathematiques-et-aide-a-la-decision.txt
# generating for : departement-telecom.txt
# generating for : emploi du temps-1ere-annee-preparatoire-section-1.json
# generating for : emploi du temps-1ere-annee-preparatoire-section-2.json
# generating for : emploi du temps-2eme-annee-preparatoire-section-1.json
# generating for : emploi du temps-2eme-annee-preparatoire-section-2.json
# generating for : emploi du temps-Big data & IA-1ere annee.json
# generating for : emploi du temps-Big data & IA-2ere annee.json
# generating for : emploi du temps-genie civile-1ere annee.json
# generating for : emploi du temps-genie civile-2ere annee.json
# generating for : emploi du temps-genie cybersecurity et systeme embarque-1ere annee.json
# generating for : emploi du temps-genie informatique-1ere annee.json
# generating for : emploi du temps-genie informatique-2ere annee.json
# generating for : emploi du temps-genie mecatronique-1ere annee.json
# generating for : emploi du temps-genie mecatronique-2ere annee.json
# generating for : emploi du temps-genie supply chain management-1ere annee.json
# generating for : emploi du temps-genie supply chain management-2ere annee.json
# generating for : emploi du temps-genie systeme telecom et reseaux-1ere annee.json
# generating for : emploi du temps-genie systeme telecom et reseaux-2ere annee.json
# generating for : formation-annees-preparatoires.txt
# generating for : formation-continue-3.txt
# generating for : formation-genie-civil.txt
# generating for : formation-genie-des-systemes-de-telecommunications-et-reseaux.txt
# generating for : formation-genie-en-cybersecurite-et-systemes-embarques.txt
# generating for : formation-genie-informatique.txt
# generating for : formation-genie-mecatronique.txt
# generating for : formation-master-ts2a.txt
# generating for : formation-science-des-donnees-big-data-intelligence-artificielle.txt
# generating for : formation-supply-chain-management.txt
# generating for : labo-Mathematics computer science and decision making.txt
# generating for : laboratoire-Ingénierie des Systèmes Innovants.txt
# generating for : laboratoire-Sciences et Technologies Industrielles et Civiles.txt
# generating for : laboratoire-Système d’Information et Génie Logiciel.txt
# generating for : Présentation de Ecole.txt
# generating for : Conventions et partenariats.txt
# generating for : Manifestations Scientifiques.txt
# generating for : projets de Recheche.txt
# generating for : Équipe de Recherche Télédétection, Systèmes et Télécommunications.txt
# Total pairs collected: 298

# %%
# Save all pairs
with open("school_dataset.jsonl", "w", encoding="utf-8") as f:
    for ex in all_pairs:
        f.write(json.dumps(ex, ensure_ascii=False) + "\n")

# %% [markdown]
# ## generate Q/A for emaloi du temps (schedules)

# %%
# ============================================
#  MAIN SCRIPT
# ============================================
if __name__ == "__main__":
    load_dotenv()
    GROQ_KEY = os.getenv("groq_api")

    if not GROQ_KEY:
        raise ValueError("Missing 'groq_api' in .env file")

    add_info = """La première question doit toujours être:
    "Quel est l'emploi du temps pour la filière X",
    où X est une des filières à l'ENSA Tétouan.
    La réponse doit toujours mentionner "pour l'année scolaire 2023-2024"."""

    current_path = Path.cwd()
    base_path = current_path.parents[0] / "data" / "data_final"
    folder_path = base_path / "emploi-temps"
    output_path = "generated_pairs.jsonl"

    WAIT_TIME = 2
    MAX_RETRIES = 3
    all_pairs = []

    print(f"Generating Q&A pairs from folder: {folder_path}\n")

    for file in os.listdir(folder_path):
        path = folder_path / file
        if not path.is_file():
            continue
        try:
            if path.suffix == ".json":
                with open(path, "r", encoding="utf-8") as f:
                    content = json.dumps(json.load(f), ensure_ascii=False)
            else:
                with open(path, "r", encoding="utf-8") as f:
                    content = f.read()

            print(f"\nGenerating for: {path.name}\n")

            for attempt in range(1, MAX_RETRIES + 1):
                try:
                    result = GenerationGroq(content, GROQ_KEY, add_info)
                    break
                except Exception as api_err:
                    print(f"Attempt {attempt}/{MAX_RETRIES} failed: {api_err}")
                    time.sleep(WAIT_TIME * attempt)
            else:
                print(f"Failed to generate for {path.name} after {MAX_RETRIES} retries.")
                continue

            # === Parse JSON lines ===
            valid_lines = 0
            for line in result.splitlines():
                line = line.strip()
                if not line:
                    continue
                try:
                    pair = json.loads(line)
                    all_pairs.append(pair)
                    valid_lines += 1
                except json.JSONDecodeError:
                    print(f"Skipped invalid JSON line: {line[:100]}...")
                    continue

            print(f"Parsed {valid_lines} valid pairs from {path.name}")
            time.sleep(WAIT_TIME)

        except Exception as e:
            print(f"Error reading {path.name}: {e}")
            continue

    # === Save dataset ===
    with open(output_path, "w", encoding="utf-8") as f:
        for pair in all_pairs:
            f.write(json.dumps(pair, ensure_ascii=False) + "\n")

    print(f"\nTotal pairs collected: {len(all_pairs)}")
    print(f"Saved dataset to: {output_path}")
# Out:
# Generating Q&A pairs from folder: c:\Users\PC Paradise\Desktop\Work\Projects\ENSATe-chatbot\data\data_final\emploi-temps
#
#
# Generating for: emploi du temps-1ere-annee-preparatoire-section-1.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"Pour l'année scolaire 2023-2024, l'emploi du temps général à l'ENSA Tétouan se présente comme suit : Lundi : Algèbre 2 (08:30-10:00, Amphi 1), Chimie générale (10:30-12:00, Amphi 1), Analyse (14:30-16:00, Amphi 2). Mardi : Anglais 1 (08:30-10:00, Salle 1), Anglais 1 (08:30-10:00, Salle 2), Algorithmique (10:30-12:00, Amphi 1, prof. A. Tahiri), Chimie (14:30-16:00, Salle 2). Mercredi : Analyse 2 (08:30-10:00, Amphi 1, prof. Filali), Thermodynamique et Statique des Fluides (10:30-12:00, Amphi 1, prof. El Khannoussi), Algèbre (14:30-16:00, Amphi 2, GR2), Activités des étudiants (14:00-18:00). Jeudi : Culture digitale (08:30-10:00, Amphi 1, prof. Idaomar), Anglais 1 (10:30-12:00, Salle 2, GR3), Thermo. (10:30-12:00, Salle 1, GR3), Algorithmique (14:30-16:00, Amphi 2, GR2), Algorithmique (16:30-18:00, Amphi 2, GR1), Analyse (14:30-16:00, Salle 2, GR1). Vendredi : Thermo. (08:30-10:00, Amphi 1, GR2), Algèbre (08:30-10:00, Salle 1, GR3), Algorithmique (10:30-12:00, Amphi 2, GR3), Algèbre (10:30-12:00, Salle 1, GR1). Samedi : Chimie (08:30-10:00, Amphi 2, GR1), Chimie (10:30-12:00, Amphi 2, GR2).","commentary":"Ensuring the answer includes the required phrase and is concise."}Parsed 1 valid pairs from emploi du temps-1ere-annee-preparatoire-section-1.json
#
# Generating for: emploi du temps-1ere-annee-preparatoire-section-2.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Ingénierie Informatique","input":"","output":"Pour l'année scolaire 2023-2024, l'emploi du temps de la filière Ingénierie Informatique comprend les modules suivants : Anglais 1 (lundi 08:30-10:00, salle 1), Chimie (lundi 08:30-10:00, amphithéâtre 2), Analyse (lundi 10:30-12:00, amphithéâtre 2), Algorithmique (lundi 14:30-16:00, amphithéâtre 1, Prof. A. Tahiri), Analyse 2 (mardi 08:30-10:00, amphithéâtre 1), Algèbre 2 (mardi 10:30-12:00, amphithéâtre 1), Algorithmique (mardi 14:30-16:00, amphithéâtre 2), Chimie (mardi 14:30-16:00, salle 1), Analyse (mardi 16:30-18:00, salle 1), Algorithmique (mardi 16:30-18:00, amphithéâtre 2), Thermodynamique (mercredi 08:30-10:00, salle 1), Algorithmique (mercredi 08:30-10:00, amphithéâtre 2), Analyse (mercredi 10:30-12:00, salle 1), Algèbre (mercredi 10:30-12:00, amphithéâtre 2), Culture digitale (mercredi 14:30-16:00, amphithéâtre 1), Activités des étudiants (mercredi 14:00-18:00).","output":"Pour l'année scolaire 2023-2024, l'emploi du temps de la filière Ingénierie Informatique comprend les modules suivants : Anglais 1 (lundi 08:30-10:00, salle 1), Chimie (lundi 08:30-10:00, amphithéâtre 2), Analyse (lundi 10:30-12:00, amphithéâtre 2), Algorithmique (lundi 14:30-16:00, amphithéâtre 1, Prof. A. Tahiri), Analyse 2 (mardi 08:30-10:00, amphithéâtre 1), Algèbre 2 (mardi 10:30-12:00, amphithéâtre 1), Algorithmique (mardi 14:30-16:00, amphithéâtre 2), Chimie (mardi 14:30-16:00, salle 1), Analyse (mardi 16:30-18:00, salle 1), Algorithmique (mardi 16:30-18:00, amphithéâtre 2), Thermodynamique (mercredi 08:30-10:00, salle 1), Algorithmique (mercredi 08:30-10:00, amphithéâtre 2), Analyse (mercredi 10:30-12:00, salle 1), Algèbre (mercredi 10:30-12:00, amphithéâtre 2), Culture digitale (mercredi 14:30-16:00, amphithéâtre 1), Activités des étudiants (mercredi 14:00-18:00).","output":"Pour l'année scolaire 2023-2024, l'emploi du temps de la filière Ingénierie Informatique comprend les modules suivants : Anglais 1 (lundi 08:30-10:00, salle 1), Chimie (lundi 08:30-10:00, amphithéâtre 2), Analyse (lundi 10:30-12:00, amphithéâtre 2), Algorithmique (lundi 14:30-16:00, amphithéâtre 1, Prof. A. Tahiri), Analyse 2 (mardi 08:30-10:00, amphithéâtre 1), Algèbre 2 (mardi 10:30-12:00, amphithéâtre 1), Algorithmique (mardi 14:30-16:00, amphithéâtre 2), Chimie (mardi 14:30-16:00, salle 1), Analyse (mardi 16:30-18:00, salle 1), Algorithmique (mardi 16:30-18:00, amphithéâtre 2), Thermodynamique (mercredi 08:30-10:00, salle 1), Algorithmique (mercredi 08:30-10:00, amphithéâtre 2), Analyse (mercredi 10:30-12:00, salle 1), Algèbre (mercredi 10:30-12:00, amphithéâtre 2), Culture digitale (mercredi 14:30-16:00, amphithéâtre 1), Activités des étudiants (mercredi 14:00-18:00).","output":"Pour l'année scolaire 2023-2024, l'emploi du temps de la filière Ingénierie Informatique comprend les modules suivants : Anglais 1 (lundi 08:30-10:00, salle 1), Chimie (lundi 08:30-10:00, amphithéâtre 2), Analyse (lundi 10:30-12:00, amphithéâtre 2), Algorithmique (lundi 14:30-16:00, amphithéâtre 1, Prof. A. Tahiri), Analyse 2 (mardi 08:30-10:00, amphithéâtre 1), Algèbre 2 (mardi 10:30-12:00, amphithéâtre 1), Algorithmique (mardi 14:30-16:00, amphithéâtre 2), Chimie (mardi 14:30-16:00, salle 1), Analyse (mardi 16:30-18:00, salle 1), Algorithmique (mardi 16:30-18:00, amphithéâtre 2), Thermodynamique (mercredi 08:30-10:00, salle 1), Algorithmique (mercredi 08:30-10:00, amphithéâtre 2), Analyse (mercredi 10:30-12:00, salle 1), Algèbre (mercredi 10:30-12:00, amphithéâtre 2), Culture digitale (mercredi 14:30-16:00, amphithéâtre 1), Activités des étudiants (mercredi 14:00-18:00)."}Parsed 1 valid pairs from emploi du temps-1ere-annee-preparatoire-section-2.json
#
# Generating for: emploi du temps-2eme-annee-preparatoire-section-1.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"L'emploi du temps pour la filière Informatique, pour l'année scolaire 2023-2024, comprend les cours d'Algorithmique, d'Analyse, d'Algèbre et de Culture digitale répartis du lundi au vendredi. Par exemple, le lundi, le module Algorithmique se tient de 14h30 à 16h00 en Amphi 1 avec le professeur A. Tahiri ; le mardi, Algorithmique est en Amphi 2 de 14h30 à 16h00 pour le groupe GR4 ; le mercredi, Algorithmique se déroule en Amphi 2 de 08h30 à 10h00 pour le groupe GR5 ; le jeudi, Algorithmique se trouve en Amphi 2 de 14h30 à 16h00 pour le groupe GR4 ; enfin, le vendredi, aucune séance d'Algorithmique n'est prévue."}{"instruction":"Où se trouve le cours d'Algorithmique le lundi ?","input":"","output":"Le cours d'Algorithmique du lundi se déroule de 14h30 à 16h00 en Amphi 1, avec le professeur A. Tahiri, pour le groupe Section 2."}{"instruction":"Quel professeur enseigne le cours de Chimie le mardi ?","input":"","output":"Le cours de Chimie du mardi se tient à 14h30-16h00 en Salle 1 ; le professeur n'est pas indiqué dans l'emploi du temps fourni."}{"instruction":"Quel est le groupe pour le cours de Thermodynamique le jeudi ?","input":"","output":"Le cours de Thermodynamique le jeudi se tient en Salle 1 à 08h30-10h00 pour le groupe GR4, à 14h30-16h00 en Salle 1 pour le groupe GR5, et à 16h30-18h00 en Salle 1 pour le groupe GR6."}{"instruction":"Quelle est la durée du cours d'Analyse le mardi ?","input":"","output":"Le cours d'Analyse du mardi dure deux heures, de 16h30 à 18h00, en Salle 1 pour le groupe GR6."}{"instruction":"Quels modules sont en salle 1 le mercredi ?","input":"","output":"Le mercredi, en Salle 1, on trouve le module Thermodynamique de 08h30 à 10h00 (groupe GR4) et l'événement étudiant de 14h00 à 18h00."}{"instruction":"Quel est l'événement étudiant le mercredi après-midi ?","input":"","output":"Il y a une activité des étudiants le mercredi de 14h00 à 18h00."}⚠️ Skipped invalid JSON line: {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"L'empl...
# Parsed 0 valid pairs from emploi du temps-2eme-annee-preparatoire-section-1.json
#
# Generating for: emploi du temps-2eme-annee-preparatoire-section-2.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"", "output":"L'emploi du temps pour l'année scolaire 2023-2024 comprend des cours de Maths, Physique, Analyse, Management et Anglais répartis tout au long de la semaine. Par exemple, le lundi, vous avez Maths de 08:30 à 10:00 (GR4) et 10:30 à 12:00 (GR5), Analyse 4 de 12:30 à 14:00 (Sections 1 et 2) avec le professeur Cherkaoui, et Anglais de 16:30 à 18:00 (GR6). Le mardi, Physique 3 de 08:30 à 10:00, Maths Appliqués de 10:30 à 12:00, et deux sessions de Management de 14:30 à 18:00, toutes en amphithéâtre. Les autres jours suivent un schéma similaire avec des cours répartis entre salles S005, S006 et l'amphithéâtre."}{"instruction":"Où se tient le cours de Physique 3 le mardi?","input":"", "output":"Le cours de Physique 3 le mardi se tient en amphithéâtre de 08:30 à 10:00."}{"instruction":"Quel professeur enseigne le Management le mardi?","input":"", "output":"Le professeur qui enseigne le Management le mardi est Ech‑Charrat."}{"instruction":"Quel est le créneau horaire du cours d'Anglais le jeudi?","input":"", "output":"Il n'y a pas de cours d'Anglais prévu le jeudi dans le planning fourni."}{"instruction":"Quelles activités étudiants sont prévues le mercredi?","input":"", "output":"Le mercredi, il y a une activité des étudiants de 14:30 à 18:00."}{"instruction":"Quand et où se déroule l'activité d'ouverture le samedi?","input":"", "output":"L'activité d'ouverture se déroule le samedi de 10:30 à 12:00 en amphithéâtre, encadrée par Belmir/Islami."}{"instruction":"Quel est le groupe pour le cours d'Analyse 4 le lundi?","input":"", "output":"Le cours d'Analyse 4 le lundi est pour les sections 1 et 2."}⚠️ Skipped invalid JSON line: {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"", "output":"L'emp...
# Parsed 0 valid pairs from emploi du temps-2eme-annee-preparatoire-section-2.json
#
# Generating for: emploi du temps-Big data & IA-1ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"L'emploi du temps pour la filière Informatique pour l'année scolaire 2023-2024 est le suivant :\n- Lundi : S105 – Algorithmique avancée et programmation (Prof. Belcaid)\n- Mardi : S105 – Visualisation des données (Prof. Sassi) ; S103 – Langues étrangères 2 (Prof. El Morabet)\n- Mercredi : S105 – Fondamentaux du Big Data (Prof. Sassi) ; Activités des étudiants\n- Jeudi : S105 – Apprentissage Automatique (Prof. Hachchane) ; Amphi – Culture & arts & sport skills (Prof. Hira)\n- Vendredi : S105 – Algèbre linéaire numérique pour l'analyse de données (Prof. Louly)\n- Samedi : Pas d'enseignements"}
# {"instruction":"Quels modules sont dispensés le mardi à l'ENSA Tétouan ?","input":"","output":"Le mardi, les modules dispensés sont : Visualisation des données (S105) et Langues étrangères 2 (S103)."}
# {"instruction":"Quel professeur enseigne l'apprentissage automatique ?","input":"","output":"Le professeur Hachchane enseigne l'apprentissage automatique."}
# {"instruction":"Y a-t-il des activités étudiantes le mercredi ?","input":"","output":"Oui, le mercredi il y a des activités des étudiants."}
# {"instruction":"Quel est le module de l'amphithéâtre le jeudi ?","input":"","output":"Le module de l'amphithéâtre le jeudi est Culture & arts & sport skills (Prof. Hira)."}
# {"instruction":"À quelle salle se déroule l'algèbre linéaire numérique le vendredi ?","input":"","output":"L'algèbre linéaire numérique pour l'analyse de données se déroule dans la salle S105 le vendredi."}Parsed 6 valid pairs from emploi du temps-Big data & IA-1ere annee.json
#
# Generating for: emploi du temps-Big data & IA-2ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"Lundi : 08:00‑10:00 S206 – Fondamentaux de l’intelligence artificielle (Prof. Belcaid), 10:30‑12:30 S206 – même cours, 14:30‑16:30 Amphi – Management 2 (Prof. Ech‑Charrat). Mardi : 08:00‑10:00 S206 – Théorie de l’information (Prof. Wadiai), 10:30‑12:30 S206 – même cours, 14:30‑16:30 S206 – Analyse du web (Prof. Sassi). Mercredi : 08:00‑10:00 S206 – Éthique et droit (Prof. Rekaloui), 10:30‑12:30 S206 – même cours, 14:30‑18:00 – Activités des étudiants. Jeudi : 08:00‑10:00 S206 – Applications de l’intelligence artificielle (Prof. Aghzout), 10:30‑12:30 S206 – même cours. Vendredi : 08:00‑10:00 S206 – Les techniques de veille (Prof. Aghzout), 10:30‑12:30 S206 – même cours. Samedi : aucun cours. (pour l’année scolaire 2023‑2024)."}
# {"instruction":"Qui donne le cours de Management 2?","input":"","output":"Le cours de Management 2 est donné par le professeur Ech‑Charrat, en amphithéâtre, le lundi de 14:30 à 16:30."}
# {"instruction":"Où se trouvent les cours d'Analyse du web?","input":"","output":"Les cours d’Analyse du web ont lieu en salle S206, le mardi de 14:30 à 16:30."}
# {"instruction":"Quand est l'activité des étudiants?","input":"","output":"L’activité des étudiants se déroule le mercredi de 14:30 à 18:00."}
# {"instruction":"Quelles matières sont enseignées le jeudi?","input":"","output":"Le jeudi, les étudiants suivent Applications de l’intelligence artificielle, 08:00‑10:00 et 10:30‑12:30 en salle S206, enseigné par le professeur Aghzout."}
# {"instruction":"Y a-t-il des cours le samedi?","input":"","output":"Non, il n’y a pas de cours le samedi."}
# {"instruction":"Qui enseigne les techniques de veille?","input":"","output":"Les techniques de veille sont enseignées par le professeur Aghzout, en salle S206, le vendredi de 08:00 à 10:00 et de 10:30 à 12:30."}Parsed 7 valid pairs from emploi du temps-Big data & IA-2ere annee.json
#
# Generating for: emploi du temps-genie civile-1ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Géotechnique","input":"","output":"Pour l'année scolaire 2023-2024, la filière Géotechnique propose les cours suivants : Géotechnique 1 le mercredi de 08:30 à 10:00 et 10:30 à 12:00, et l'activité des étudiants de 14:30 à 18:00."}{"instruction":"Qui est le professeur de Mécanique des fluides et où se déroule le cours ?","input":"","output":"Pour l'année scolaire 2023-2024, le professeur de Mécanique des fluides est El Khannoussi, enseignement à S103 le lundi de 08:30 à 10:00 et 10:30 à 12:00."}{"instruction":"À quelle heure se passe l'activité des étudiants le mercredi ?","input":"","output":"Pour l'année scolaire 2023-2024, le mercredi de 14:30 à 18:00 est réservé aux activités des étudiants."}{"instruction":"Où se tient la séance Culture & arts & sport skills le jeudi ?","input":"","output":"Pour l'année scolaire 2023-2024, Culture & arts & sport skills se tient le jeudi 14:30-16:00 à l'Amphi, dirigé par Hira."}{"instruction":"Combien de fois le lundi on enseigne Mécanique des fluides et à quel endroit ?","input":"","output":"Pour l'année scolaire 2023-2024, le lundi, Mécanique des fluides se donne deux séances : 08:30-10:00 et 10:30-12:00 à S103."}{"instruction":"Y a-t-il des cours le samedi ?","input":"","output":"Pour l'année scolaire 2023-2024, il n'y a aucune activité prévue le samedi."}{"instruction":"Combien d'heures par semaine pour Topographie et urbanisme ?","input":"","output":"Pour l'année scolaire 2023-2024, Topographie et urbanisme se donne le vendredi deux fois (08:30-10:00 et 10:30-12:00), soit 4 heures hebdomadaires."}⚠️ Skipped invalid JSON line: {"instruction":"Quel est l'emploi du temps pour la filière Géotechnique","input":"","output":"Pour l...
# Parsed 0 valid pairs from emploi du temps-genie civile-1ere annee.json
#
# Generating for: emploi du temps-genie civile-2ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Construction métallique","input":"","output":"Pour l'année scolaire 2023-2024, l'emploi du temps de la filière Construction métallique est le suivant : \nLundi : 08:00-10:00 – Construction métallique (S200, Prof. Attajkani) ; 10:30-12:30 – TD Construction métallique (S200, Prof. Attajkani) ; 14:30-16:30 – Management 2 (Amphi, Prof. Ech-Charrat). \nMardi : 08:00-10:00 – Routes (S200, Prof. Bannour) ; 10:30-12:30 – TD Routes (S200, Prof. Bannour). \nMercredi : 08:00-10:00 – Calcul des structures (S200, Prof. El-Bakari) ; 10:30-12:30 – TD Calcul des structures (S200, Prof. El-Bakari) ; 14:30-18:00 – Activités des étudiants. \nJeudi : 08:00-10:00 – Béton armé (S200, Prof. Attajkani) ; 10:30-12:30 – TD Béton armé (S200, Prof. Attajkani). \nVendredi : 08:00-10:00 – Hydraulique urbaine (S200, Prof. M.Tahiri) ; 10:30-12:30 – TD Hydraulique urbaine (S200, Prof. M.Tahiri). \nSamedi : pas de cours."}
# {"instruction":"Où se tient le cours de Management 2 ?","input":"","output":"Le cours de Management 2 se tient en amphithéâtre (Amphi) le lundi de 14:30 à 16:30, pour l'année scolaire 2023-2024."}
# {"instruction":"Qui enseigne le module Béton armé ?","input":"","output":"Le module Béton armé est enseigné par le Professeur Attajkani, pour l'année scolaire 2023-2024."}
# {"instruction":"Y a-t-il des cours le samedi à ENSA Tétouan ?","input":"","output":"Non, le samedi est libre de tout cours pour l'année scolaire 2023-2024."}
# {"instruction":"Quelles activités sont prévues le mercredi après-midi ?","input":"","output":"Le mercredi après-midi, de 14:30 à 18:00, des activités des étudiants sont organisées, pour l'année scolaire 2023-2024."}
# {"instruction":"Où puis-je trouver le planning complet de l'année scolaire 2023-2024 ?","input":"","output":"Vous pouvez consulter le planning complet sur le site officiel de l'ENSA Tétouan ou demander au service administratif de la faculté, pour l'année scolaire 2023-2024."}Parsed 6 valid pairs from emploi du temps-genie civile-2ere annee.json
#
# Generating for: emploi du temps-genie cybersecurity et systeme embarque-1ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique industrielle","input":"","output":"Pour l'année scolaire 2023-2024, l'emploi du temps de la filière Informatique industrielle est : Lundi 10:30-12:00 et 14:30-16:00, salle S004, professeur Baghouri."}
# {"instruction":"Où se tiennent les cours d'Architectures et programmation DSP ?","input":"","output":"Pour l'année scolaire 2023-2024, les cours d'Architectures et programmation DSP se tiennent à la salle S004, du mardi 08:30-10:00 et 10:30-12:00, avec le professeur Errachidi."}
# {"instruction":"Qui enseigne le module Réseaux avancés : routage et commutation ?","input":"","output":"Pour l'année scolaire 2023-2024, le module Réseaux avancés : routage et commutation est enseigné par le professeur Aytouna, du jeudi 08:30-10:00 et 10:30-12:00, à la salle S004."}
# {"instruction":"Quelle activité est prévue le mercredi après-midi ?","input":"","output":"Pour l'année scolaire 2023-2024, le mercredi 14:30-18:00 est réservé aux activités des étudiants."}
# {"instruction":"Y a-t-il des cours le samedi à ENSA Tétouan ?","input":"","output":"Pour l'année scolaire 2023-2024, il n'y a aucun cours le samedi."}
# {"instruction":"Quand se déroule le module Culture & arts & sport skills ?","input":"","output":"Pour l'année scolaire 2023-2024, le module Culture & arts & sport skills se déroule le jeudi 14:30-16:00 à l'Amphi, avec le professeur Hira."}
# {"instruction":"Quel est l'emplacement des cours de l'Introduction à la sécurité des systèmes embarqués ?","input":"","output":"Pour l'année scolaire 2023-2024, les cours d'Introduction à la sécurité des systèmes embarqués se tiennent à la salle S004, du mercredi 08:30-10:00 et 10:30-12:00, avec le professeur Wadiai."}Parsed 7 valid pairs from emploi du temps-genie cybersecurity et systeme embarque-1ere annee.json
#
# Generating for: emploi du temps-genie informatique-1ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"L'emploi du temps pour la filière Informatique pour l'année scolaire 2023-2024 est le suivant : Lundi : 08:30-10:00 TP1 Théories des Langages et Compilation, 10:30-12:00 Théories des Langages et Compilation, 14:30-16:00 TP2 Théories des Langages et Compilation ; Mardi : 08:30-10:00 TP2 Développement Web, 10:30-12:00 Développement Web, 12:30-14:00 TP1 Développement Web, 14:30-16:00 Langues étrangères 2 ; Mercredi : 08:30-10:00 Modélisation Orientée Objet, 10:30-12:00 Modélisation Orientée Objet, 14:30-18:00 Activités des étudiants ; Jeudi : 08:30-10:00 TP1 Programmation Orientée Objet Java, 10:30-12:00 Programmation Orientée Objet Java, 12:30-14:00 TP2 Programmation Orientée Objet Java, 14:30-16:00 Culture & arts & sport skills ; Vendredi : 08:30-10:00 TP2 Systèmes d’Exploitation et Linux, 10:30-12:00 Systèmes d’Exploitation et Linux, 14:30-16:00 TP1 Systèmes d’Exploitation et Linux."}{"instruction":"Où se tiennent les cours de TP1 Théories des Langages et Compilation le lundi ?","input":"","output":"Les TP1 Théories des Langages et Compilation le lundi se tiennent à la salle STPI7, de 08:30 à 10:00, pour l'année scolaire 2023-2024."}{"instruction":"Qui enseigne le module Développement Web mardi ?","input":"","output":"Le module Développement Web mardi est enseigné par le professeur Jourani, pour l'année scolaire 2023-2024."}{"instruction":"Y a-t-il des cours en dehors du STPI7 ?","input":"","output":"Oui, le cours Langues étrangères 2 le mardi 14:30-16:00 se déroule dans la salle CRL, et le cours Culture & arts & sport skills le jeudi 14:30-16:00 se tient à l'Amphi, pour l'année scolaire 2023-2024."}{"instruction":"Quel est le créneau horaire des activités des étudiants le mercredi ?","input":"","output":"Les activités des étudiants le mercredi se tiennent de 14:30 à 18:00, sans lieu précis indiqué, pour l'année scolaire 2023-2024."}{"instruction":"Combien de TP sont prévus pour la semaine ?","input":"","output":"La semaine comprend six TP : TP1 et TP2 Théories des Langages et Compilation, TP2 et TP1 Développement Web, TP1 et TP2 Programmation Orientée Objet Java, TP1 et TP2 Systèmes d’Exploitation et Linux, pour l'année scolaire 2023-2024."}{"instruction":"Quelle salle est utilisée pour le cours de Modélisation Orientée Objet ?","input":"","output":"Le cours Modélisation Orientée Objet se tient à la salle STPI7, le lundi et mardi de 08:30 à 12:00, pour l'année scolaire 2023-2024."}⚠️ Skipped invalid JSON line: {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"L'empl...
# Parsed 0 valid pairs from emploi du temps-genie informatique-1ere annee.json
#
# Generating for: emploi du temps-genie informatique-2ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"L’emploi du temps pour la filière Informatique, pour l'année scolaire 2023-2024, se compose des séances suivantes :\n- Lundi : Management 2 en amphithéâtre de 14h00 à 16h00 et 16h30 à 18h00 (Prof. Ech‑Charrat).\n- Mardi : TP‑1 et TP‑2 Bases de Données relationnelles en salle S205 de 08h00 à 10h00, 10h30 à 12h30, 14h00 à 16h00 (Prof. Chrayah).\n- Mercredi : TP‑2 et TP‑1 Intelligence artificielle en salle S205 de 08h00 à 10h00, 10h30 à 12h30, 14h00 à 16h00 (Prof. El Younoussi). Après 16h30, activités étudiantes.\n- Jeudi : TP‑1 et TP‑2 Programmation Web 2 en salle S205 de 08h00 à 10h00, 10h30 à 12h30, 14h00 à 16h00 (Prof. Al Achhab).\n- Vendredi : TP‑1 et TP‑2 Programmation réseaux et sécurité Info en salle S205 de 10h30 à 12h30, 14h00 à 16h00, 16h30 à 18h00 (Prof. A. Tahiri).\n- Samedi : TP‑1 et TP‑2 Java avancé en salle S205 de 08h00 à 10h00, 10h30 à 12h30, 14h00 à 16h00 (Prof. El Hajjamy)."}
# {"instruction":"À quelle heure commence le cours de Management 2 lundi?","input":"","output":"Le cours de Management 2 commence à 14h00 le lundi."}
# {"instruction":"Qui enseigne le TP‑1 Bases de Données relationnelles?","input":"","output":"Le TP‑1 Bases de Données relationnelles est enseigné par le professeur Chrayah."}
# {"instruction":"Où se tient le cours d'Intelligence artificielle le mercredi après-midi?","input":"","output":"Le cours d'Intelligence artificielle du mercredi après-midi se tient en salle S205."}
# {"instruction":"Y a-t-il des activités étudiantes le jeudi?","input":"","output":"Non, il n'y a pas d'activités étudiantes prévues le jeudi."}Parsed 5 valid pairs from emploi du temps-genie informatique-2ere annee.json
#
# Generating for: emploi du temps-genie mecatronique-1ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Électrotechnique","input":"","output":"L'emploi du temps pour la filière Électrotechnique, pour l'année scolaire 2023-2024, comprend les modules suivants :\n- Lundi : Langues étrangères 2 (10:30-12:00) à CRL.\n- Mardi : Matériaux pour l'industrie et RDM (08:30-10:00 et 10:30-12:00) à S106.\n- Mercredi : Automatique (08:30-10:00 et 10:30-12:00) à S106, puis activités étudiantes (14:30-18:00).\n- Jeudi : Culture & arts & sport skills (12:30-14:00) à Amphi, Mécanique (14:30-16:00 et 16:30-18:00) à S106.\n- Vendredi : Énergétique et Mécanique des Fluides (08:30-10:00 et 10:30-12:00) à S106, Modélisation et POO (14:30-16:00 et 16:30-18:00) à Amphi.\n- Samedi : Pas de cours."}{"instruction":"Quelles sont les heures de cours de la semaine pour le module 'Automatique'?","input":"","output":"Le module 'Automatique' se donne à S106 aux horaires suivants :\n- Mercredi 08:30-10:00\n- Mercredi 10:30-12:00"}{"instruction":"Où se tient le cours de 'Matériaux pour l'industrie et RDM'?","input":"","output":"Le cours 'Matériaux pour l'industrie et RDM' se tient à la salle S106, les mardi 08:30-10:00 et 10:30-12:00."}{"instruction":"Qui est le professeur du module 'Modélisation et POO'?","input":"","output":"Le professeur du module 'Modélisation et POO' est Jourani."}{"instruction":"Quand y a-t-il des activités étudiantes?","input":"","output":"Les activités étudiantes ont lieu le mercredi de 14:30 à 18:00."}{"instruction":"Quel est le jour où il n'y a pas de cours?","input":"","output":"Il n'y a pas de cours le samedi."}⚠️ Skipped invalid JSON line: {"instruction":"Quel est l'emploi du temps pour la filière Électrotechnique","input":"","output":"L'...
# Parsed 0 valid pairs from emploi du temps-genie mecatronique-1ere annee.json
#
# Generating for: emploi du temps-genie mecatronique-2ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"Voici l'emploi du temps complet de la filière Informatique pour l'année scolaire 2023-2024 (semaine type) :\nLundi : 08h-10h Conception des machines (S202) – Professeur Nasri ; 10h30-12h30 TD Conception des machines (S202) – Professeur Nasri ; 14h-16h Management 2 (Amphi) – Professeur Ech-Charrat ; 16h30-18h Management 2 (Amphi) – Professeur Ech-Charrat.\nMardi : 08h-10h Automatisation et Instrumentation (S202) – Professeur Chouiekh/Haddi ; 10h30-12h30 TD Automatisation et Instrumentation (S202) – Professeur Chouiekh/Haddi.\nMercredi : 08h-10h Electronique embarquée (S202) – Professeur Moutakki/Zakriti ; 10h30-12h30 TD Electronique embarquée (S202) – Professeur Moutakki/Zakriti ; 14h-18h Activités des étudiants.\nJeudi : 08h-10h Technologie de l'automobile (S202) – Professeur O.Benzarouala/Moutakki ; 10h30-12h30 TD Technologie de l'automobile (S202) – Professeur O.Benzarouala/Moutakki.\nVendredi : 08h-10h Actionneurs (S202) – Professeur Haddi/Sanbi ; 10h30-12h30 TD Actionneurs (S202) – Professeur Haddi/Sanbi.\nSamedi : 08h-10h TP Actionneurs (S202) – Professeur Haddi ; 10h30-12h30 TP Actionneurs (S202) – Professeur Haddi."}{"instruction":"Où se déroule le TD de la Conception des machines ?","input":"","output":"Le TD de la Conception des machines se tient dans la salle S202, de 10h30 à 12h30, chaque lundi."}{"instruction":"Qui est le professeur de l'Automatisation et Instrumentation ?","input":"","output":"Le professeur de l'Automatisation et Instrumentation est Chouiekh/Haddi."}{"instruction":"Y a-t-il des journées sans cours ?","input":"","output":"Oui, le mercredi après 12h30 il n'y a pas de cours; il y a une activité des étudiants de 14h à 18h."}{"instruction":"Que dois-je apporter pour le TP Actionneurs ?","input":"","output":"Apportez votre carnet, un ordinateur portable si nécessaire, les outils de base (pinces, tournevis) et votre badge d'étudiant."}{"instruction":"Quelles activités sont prévues le mercredi après-midi ?","input":"","output":"Le mercredi après-midi, il y a des activités des étudiants de 14h à 18h, sans cours."}⚠️ Skipped invalid JSON line: {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"Voici ...
# Parsed 0 valid pairs from emploi du temps-genie mecatronique-2ere annee.json
#
# Generating for: emploi du temps-genie supply chain management-1ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Génie Informatique","input":"","output":"L'emploi du temps pour la filière Génie Informatique pour l'année scolaire 2023-2024 est le suivant : Lundi : 14:30 - 16:00 et 16:30 - 18:00 en S003 (Management de la qualité) ; Mardi : 08:30 - 10:00 et 10:30 - 12:00 en S003 (Techniques d'achat et de réduction des coûts), 14:30 - 16:00 et 16:30 - 18:00 en S003 (Modélisation & évaluation des performances des systèmes industriels) ; Mercredi : 08:30 - 10:00 et 10:30 - 12:00 en S003 (Apprentissage automatique), 14:30 - 18:00 (Activités des étudiants) ; Jeudi : 08:30 - 10:00 et 10:30 - 12:00 en S003 (Optimisation combinatoire), 14:30 - 16:00 en Amphi (Culture & arts & sport skills) ; Vendredi : 08:30 - 10:00 en CRL (Langues étrangères 2), 14:30 - 16:00 et 16:30 - 18:00 en Amphi (Modélisation et POO) ; Samedi : aucune session."}{"instruction":"Quel est le nom du professeur de la séance de Modélisation & évaluation des performances des systèmes industriels ?","input":"","output":"Le professeur de la séance de Modélisation & évaluation des performances des systèmes industriels est Larioui."}{"instruction":"Où se déroule la session d'Optimisation combinatoire ?","input":"","output":"La session d'Optimisation combinatoire se déroule en S003."}{"instruction":"À quelle heure commence l'Activité des étudiants le mercredi ?","input":"","output":"L'Activité des étudiants le mercredi commence à 14:30."}{"instruction":"Quel module est dispensé le jeudi après 14h ?","input":"","output":"Le module dispensé le jeudi après 14h est Culture & arts & sport skills."}{"instruction":"Qui enseigne la session de Langues étrangères 2 ?","input":"","output":"La session de Langues étrangères 2 est enseignée par Nejjari et Malla Hussein."}{"instruction":"Combien de cours en Modélisation et POO sont planifiés le vendredi ?","input":"","output":"Il y a deux cours en Modélisation et POO prévus le vendredi, de 14:30 à 16:00 et de 16:30 à 18:00."}⚠️ Skipped invalid JSON line: {"instruction":"Quel est l'emploi du temps pour la filière Génie Informatique","input":"","output":"...
# Parsed 0 valid pairs from emploi du temps-genie supply chain management-1ere annee.json
#
# Generating for: emploi du temps-genie supply chain management-2ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Management","input":"","output":"Voici l'emploi du temps pour la filière Management pour l'année scolaire 2023-2024 : \n- Lundi : 14:00-16:00 et 16:30-18:00 – Management 2 – Professeur Ech‑Charrat – Amphi.\n- Mardi : 08:00-10:00 et 10:30-12:30 – Exploration et analyse des données – Ech‑Charrat – S204.\n- Mardi : 14:00-16:00 et 16:30-18:00 – Analyse Fonctionnelle et Analyse de la valeur – Sarir – S204.\n- Mercredi : 08:00-10:00 et 10:30-12:30 – Ordonnancement de la production – Ben Yakoub – S204.\n- Mercredi : 14:00-18:00 – Activités des étudiants.\n- Jeudi : 14:00-16:00 et 16:30-18:00 – Théorie de l'aide à la décision – Ait Lhassan – S204.\n- Vendredi : 08:00-10:00 et 10:30-12:30 – Technologie Entreprise – S204."}
# {"instruction":"Combien d'heures de cours hebdomadaires a-t-on pour la module 'Analyse Fonctionnelle et Analyse de la valeur' ?","input":"","output":"La module 'Analyse Fonctionnelle et Analyse de la valeur' se déroule le mardi de 14h00 à 16h00 et de 16h30 à 18h00, soit 4 heures par semaine."}
# {"instruction":"Où se tiennent les cours de 'Théorie de l'aide à la décision' ?","input":"","output":"Les cours de 'Théorie de l'aide à la décision' ont lieu le jeudi, de 14h00 à 16h00 et de 16h30 à 18h00, dans la salle S204."}
# {"instruction":"Qui enseigne le module 'Exploration et analyse des données' ?","input":"","output":"Le module 'Exploration et analyse des données' est dispensé par le professeur Ech‑Charrat."}
# {"instruction":"Quel est l'événement prévu le mercredi après-midi ?","input":"","output":"Le mercredi après-midi, de 14h00 à 18h00, il est prévu une 'Activités des étudiants'."}
# {"instruction":"Y a-t-il des cours le samedi ?","input":"","output":"Non, il n'y a aucun cours prévu le samedi."}
# {"instruction":"Combien de cours de 'Technologie Entreprise' ont lieu le vendredi ?","input":"","output":"Le vendredi, il y a deux séances de 'Technologie Entreprise', de 08h00 à 10h00 et de 10h30 à 12h30, toutes deux en salle S204."}Parsed 7 valid pairs from emploi du temps-genie supply chain management-2ere annee.json
#
# Generating for: emploi du temps-genie systeme telecom et reseaux-1ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Informatique","input":"","output":"L’emploi du temps de la filière Informatique pour l'année scolaire 2023-2024 comprend les cours suivants : \n- Lundi : Conception des circuits VLSI (08:30-10:00, 10:30-12:00) et Apprentissage Automatique et Applications (14:30-16:00). \n- Mardi : Électronique Analogique pour les Télécommunications (08:30-10:00, 10:30-12:00) et Langues étrangères 2 (12:30-14:00). \n- Mercredi : Apprentissage Automatique et Applications (08:30-10:00, 10:30-12:00) et Activités des étudiants (14:30-18:00). \n- Jeudi : Modulation numérique (08:30-10:00, 10:30-12:00) et Culture & arts & sport skills (12:30-14:00). \n- Vendredi : Modélisation et POO (14:30-16:00, 16:30-18:00)."}
# {"instruction":"Où se tient le cours d'Apprentissage Automatique le lundi après-midi ?","input":"","output":"Le cours d'Apprentissage Automatique et Applications se tient en salle S104, du lundi 14:30 au 16:00."}
# {"instruction":"Quand commence le cours de Modulation numérique ?","input":"","output":"Le cours de Modulation numérique commence à 08:30 le lundi et le jeudi."}
# {"instruction":"Quelle est la durée du cours de Modélisation et POO ?","input":"","output":"Le cours de Modélisation et POO dure 2 heures, soit 14:30-16:00 et 16:30-18:00 le vendredi."}
# {"instruction":"Y a-t-il des cours le samedi ?","input":"","output":"Non, il n'y a aucun cours prévu le samedi."}
# {"instruction":"Quel professeur enseigne la Langues étrangères 2 ?","input":"","output":"La Langues étrangères 2 est enseignée par Nejjari/Malla Hussein."}
# {"instruction":"Quel est l'événement du mercredi après-midi ?","input":"","output":"Le mercredi après-midi, de 14:30 à 18:00, il y a les Activités des étudiants."}Parsed 7 valid pairs from emploi du temps-genie systeme telecom et reseaux-1ere annee.json
#
# Generating for: emploi du temps-genie systeme telecom et reseaux-2ere annee.json
#
# {"instruction":"Quel est l'emploi du temps pour la filière Systèmes embarqués et temps réel","input":"","output":"L’emploi du temps de la filière Systèmes embarqués et temps réel est le suivant : mardi 08:00-10:00 S203 – cours, mardi 10:30-12:30 S203 – TD. (pour l'année scolaire 2023-2024)"}
# {"instruction":"Qui enseigne le cours de Management 2 et où se tient-il?","input":"","output":"Le cours de Management 2 est donné par Ech‑Charrat. Il se tient en amphithéâtre à 14:00-16:00 et 16:30-18:00 le lundi. (pour l'année scolaire 2023-2024)"}
# {"instruction":"À quelle heure commence le TP de C# et bases de données relationnelles?","input":"","output":"Le TP de C# et bases de données relationnelles commence à 10:30 le vendredi, dans le STPI6. (pour l'année scolaire 2023-2024)"}
# {"instruction":"Y a-t-il des activités étudiantes le mercredi après-midi?","input":"","output":"Oui, le mercredi après‑midi (14:00‑18:00) est réservé aux activités des étudiants. (pour l'année scolaire 2023-2024)"}
# {"instruction":"Quel est le lieu de la TD de Traitement de l'image et de la parole?","input":"","output":"La TD de Traitement de l'image et de la parole se déroule en salle S203, 10:30‑12:30 le jeudi. (pour l'année scolaire 2023-2024)"}
# {"instruction":"Combien de cours de Systèmes répartis et sécurité ont lieu le lundi?","input":"","output":"Le lundi, il y a deux cours de Systèmes répartis et sécurité : TP 08:00-10:00 STPI6 et cours 10:30-12:30 S203. (pour l'année scolaire 2023-2024)"}Parsed 6 valid pairs from emploi du temps-genie systeme telecom et reseaux-2ere annee.json
#
# Total pairs collected: 53
# Saved dataset to: c:\Users\PC Paradise\Desktop\Work\Projects\ENSATe-chatbot\data\data_final\generated_pairs.jsonl

# %% [markdown]
# ## generate Q/A in general for each split of files

# %%
import os
import json
import time
import textwrap
from pathlib import Path
from dotenv import load_dotenv
from groq import Groq

# =====================================
#          SETTINGS
# =====================================
load_dotenv()

# List of multiple API keys (from your .env or hard-coded)
API_KEYS = [
    os.getenv("groq_api_1"),
    os.getenv("groq_api_2"),
    os.getenv("groq_api_3"),
    os.getenv("groq_api_4"),
    os.getenv("groq_api_5"),
    os.getenv("groq_api_6"),
    os.getenv("groq_api_7"),
    os.getenv("groq_api_8"),
    os.getenv("groq_api_9"),

]
KEY_INDEX = 0  # start with the first key

current_path = Path.cwd()
target_file = current_path.parents[0]

BASE_PATH = target_file / "data" / "data_final"
OUTPUT_FILE = "all_generated_pairs.jsonl"
ADD_INFO = ""
MAX_CONTEXT_CHARS = 6000
MAX_BATCHES_PER_FILE = 3
SLEEP_BETWEEN_CALLS = 5
RETRY_DELAY = 20  # seconds if all keys fail

# %%
# =====================================
#  Helper: Get current API key
# =====================================
def get_current_key():
    global KEY_INDEX
    return API_KEYS[KEY_INDEX]

# %%
# =====================================
#  Helper: Rotate to next API key
# =====================================
def rotate_key():
    global KEY_INDEX
    KEY_INDEX = (KEY_INDEX + 1) % len(API_KEYS)
    print(f"Switching to API key #{KEY_INDEX + 1}")

# %%
# =====================================
#  Function to split text safely
# =====================================
def split_text(text, max_chars=MAX_CONTEXT_CHARS):
    paragraphs = text.split("\n")
    chunks, current_chunk = [], ""
    for p in paragraphs:
        if len(current_chunk) + len(p) + 1 < max_chars:
            current_chunk += p + "\n"
        else:
            chunks.append(current_chunk.strip())
            current_chunk = p + "\n"
    if current_chunk.strip():
        chunks.append(current_chunk.strip())
    return chunks

# %%
# =====================================
#  Function to generate Q&A pairs
# =====================================
def generate_groq(content, add_info="", temperature=0.3, max_tokens=4096, retries=3):
    global KEY_INDEX
    attempt = 0

    while attempt < retries * len(API_KEYS):
        api_key = get_current_key()
        client = Groq(api_key=api_key)

        prompt = f"""
        You are an assistant generating realistic question–answer pairs to use them to train a chatbot about ENSA Tétouan.

        Context:
        {content}

        Your goal:
        - Generate 5 to 10 diverse and relevant Q&A pairs.
        - Each question should sound natural from a student.
        - Answers must be factual, concise, and in French.
        - Each question should contains context, because Q/R est independante.
        - {add_info}

        Output format:
        Each line must be valid JSON:
        {{"instruction": "student question", "input": "", "output": "assistant answer"}}

        Do not include anything else.
        """

        try:
            completion = client.chat.completions.create(
                model="openai/gpt-oss-120b", 
                messages=[{"role": "user", "content": prompt}],
                temperature=temperature,
                max_completion_tokens=max_tokens,
                top_p=0.9,
                reasoning_effort="medium",
            )
            return completion.choices[0].message.content.strip()

        except Exception as e:
            print(f"Error with key #{KEY_INDEX + 1}: {e}")
            rotate_key()
            attempt += 1
            time.sleep(3)

    print(f"All keys failed. Waiting {RETRY_DELAY}s before retry...")
    time.sleep(RETRY_DELAY)
    return generate_groq(content, add_info, temperature, max_tokens, retries)

# %%
# =====================================
#  MAIN PIPELINE
# =====================================
all_pairs = []
seen_questions = set()

for folder in os.listdir(BASE_PATH):
    folder_path = BASE_PATH / folder
    if not folder_path.is_dir():
        continue

    for file in os.listdir(folder_path):
        path = folder_path / file
        if not path.is_file():
            continue

        print(f"\nProcessing: {path.name}")
        try:
            # Load content
            if path.suffix == ".json":
                with open(path, "r", encoding="utf-8") as f:
                    content = json.dumps(json.load(f), ensure_ascii=False)
            else:
                with open(path, "r", encoding="utf-8") as f:
                    content = f.read()

            chunks = split_text(content)
            file_pairs = []

            for i, chunk in enumerate(chunks[:MAX_BATCHES_PER_FILE]):
                print(f" → Generating batch {i+1}/{len(chunks)} ...")
                ADD_INFO = f"More context : {path.name}"
                result = generate_groq(chunk, ADD_INFO)
                time.sleep(SLEEP_BETWEEN_CALLS)

                for line in result.splitlines():
                    try:
                        pair = json.loads(line)
                        q = pair.get("instruction", "").strip()
                        if q and q not in seen_questions:
                            all_pairs.append(pair)
                            file_pairs.append(pair)
                            seen_questions.add(q)
                    except json.JSONDecodeError:
                        continue

            print(f" {len(file_pairs)} pairs added from {path.name}")
            # Save progress after each file
            with open(OUTPUT_FILE, "a", encoding="utf-8") as f:
                for pair in file_pairs:
                    json.dump(pair, f, ensure_ascii=False)
                    f.write("\n")
            print(f"Progress saved after {path.name}")


        except Exception as e:
            print(f"Error reading {path.name}: {e}")
            continue
# Out:
# Processing: calendrier-printemps-2025
#  → Generating batch 1/1 ...
#  7 pairs added from calendrier-printemps-2025
# Progress saved after calendrier-printemps-2025
#
# Processing: les clubs de lecole.txt
#  → Generating batch 1/3 ...
#  → Generating batch 2/3 ...
#  → Generating batch 3/3 ...
#  21 pairs added from les clubs de lecole.txt
# Progress saved after les clubs de lecole.txt
#
# Processing: commission Culturelle et Activités Sportive issue du Conseil d’établissement.txt
#  → Generating batch 1/1 ...
#  7 pairs added from commission Culturelle et Activités Sportive issue du Conseil d’établissement.txt
# Progress saved after commission Culturelle et Activités Sportive issue du Conseil d’établissement.txt
#
# Processing: Commission de coordination et de suivi du budget issue du conseil d’établissement.txt
#  → Generating batch 1/1 ...
#  7 pairs added from Commission de coordination et de suivi du budget issue du conseil d’établissement.txt
# Progress saved after Commission de coordination et de suivi du budget issue du conseil d’établissement.txt
#
# Processing: Commission de Recherche Scientifique et Coopération issue du Conseil d’Établissement.txt
#  → Generating batch 1/1 ...
#  8 pairs added from Commission de Recherche Scientifique et Coopération issue du Conseil d’Établissement.txt
# Progress saved after Commission de Recherche Scientifique et Coopération issue du Conseil d’Établissement.txt
#
# Processing: commission pédagogique issue du Conseil d’Établissement.txt
#  → Generating batch 1/1 ...
#  0 pairs added from commission pédagogique issue du Conseil d’Établissement.txt
# Progress saved after commission pédagogique issue du Conseil d’Établissement.txt
#
# Processing: Commission.txt
#  → Generating batch 1/1 ...
#  9 pairs added from Commission.txt
# Progress saved after Commission.txt
#
# Processing: Membres Conseil Etablissement.txt
#  → Generating batch 1/1 ...
#  7 pairs added from Membres Conseil Etablissement.txt
# Progress saved after Membres Conseil Etablissement.txt
#
# Processing: departement-genie-informatique.txt
#  → Generating batch 1/1 ...
#  7 pairs added from departement-genie-informatique.txt
# Progress saved after departement-genie-informatique.txt
#
# Processing: departement-humanites.txt
#  → Generating batch 1/1 ...
#  7 pairs added from departement-humanites.txt
# Progress saved after departement-humanites.txt
#
# Processing: departement-ingenierie-et-technologie-des-systemes-industriels-itsi.txt
#  → Generating batch 1/1 ...
#  7 pairs added from departement-ingenierie-et-technologie-des-systemes-industriels-itsi.txt
# Progress saved after departement-ingenierie-et-technologie-des-systemes-industriels-itsi.txt
#
# Processing: departement-intelligence-artificielle-et-digitalisation-iad.txt
#  → Generating batch 1/1 ...
#  7 pairs added from departement-intelligence-artificielle-et-digitalisation-iad.txt
# Progress saved after departement-intelligence-artificielle-et-digitalisation-iad.txt
#
# Processing: departement-sciences-et-technologies-industrielles-et-civiles-stic.txt
#  → Generating batch 1/1 ...
#  8 pairs added from departement-sciences-et-technologies-industrielles-et-civiles-stic.txt
# Progress saved after departement-sciences-et-technologies-industrielles-et-civiles-stic.txt
#
# Processing: departement-sciences-mathematiques-et-aide-a-la-decision.txt
#  → Generating batch 1/1 ...
#  7 pairs added from departement-sciences-mathematiques-et-aide-a-la-decision.txt
# Progress saved after departement-sciences-mathematiques-et-aide-a-la-decision.txt
#
# Processing: departement-telecom.txt
#  → Generating batch 1/1 ...
#  7 pairs added from departement-telecom.txt
# Progress saved after departement-telecom.txt
#
# Processing: emploi du temps-1ere-annee-preparatoire-section-1.json
#  → Generating batch 1/1 ...
#  10 pairs added from emploi du temps-1ere-annee-preparatoire-section-1.json
# Progress saved after emploi du temps-1ere-annee-preparatoire-section-1.json
#
# Processing: emploi du temps-1ere-annee-preparatoire-section-2.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-1ere-annee-preparatoire-section-2.json
# Progress saved after emploi du temps-1ere-annee-preparatoire-section-2.json
#
# Processing: emploi du temps-2eme-annee-preparatoire-section-1.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-2eme-annee-preparatoire-section-1.json
# Progress saved after emploi du temps-2eme-annee-preparatoire-section-1.json
#
# Processing: emploi du temps-2eme-annee-preparatoire-section-2.json
#  → Generating batch 1/1 ...
#  10 pairs added from emploi du temps-2eme-annee-preparatoire-section-2.json
# Progress saved after emploi du temps-2eme-annee-preparatoire-section-2.json
#
# Processing: emploi du temps-Big data & IA-1ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-Big data & IA-1ere annee.json
# Progress saved after emploi du temps-Big data & IA-1ere annee.json
#
# Processing: emploi du temps-Big data & IA-2ere annee.json
#  → Generating batch 1/1 ...
#  8 pairs added from emploi du temps-Big data & IA-2ere annee.json
# Progress saved after emploi du temps-Big data & IA-2ere annee.json
#
# Processing: emploi du temps-genie civile-1ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-genie civile-1ere annee.json
# Progress saved after emploi du temps-genie civile-1ere annee.json
#
# Processing: emploi du temps-genie civile-2ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-genie civile-2ere annee.json
# Progress saved after emploi du temps-genie civile-2ere annee.json
#
# Processing: emploi du temps-genie cybersecurity et systeme embarque-1ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-genie cybersecurity et systeme embarque-1ere annee.json
# Progress saved after emploi du temps-genie cybersecurity et systeme embarque-1ere annee.json
#
# Processing: emploi du temps-genie informatique-1ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-genie informatique-1ere annee.json
# Progress saved after emploi du temps-genie informatique-1ere annee.json
#
# Processing: emploi du temps-genie informatique-2ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-genie informatique-2ere annee.json
# Progress saved after emploi du temps-genie informatique-2ere annee.json
#
# Processing: emploi du temps-genie mecatronique-1ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-genie mecatronique-1ere annee.json
# Progress saved after emploi du temps-genie mecatronique-1ere annee.json
#
# Processing: emploi du temps-genie mecatronique-2ere annee.json
#  → Generating batch 1/1 ...
#  10 pairs added from emploi du temps-genie mecatronique-2ere annee.json
# Progress saved after emploi du temps-genie mecatronique-2ere annee.json
#
# Processing: emploi du temps-genie supply chain management-1ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-genie supply chain management-1ere annee.json
# Progress saved after emploi du temps-genie supply chain management-1ere annee.json
#
# Processing: emploi du temps-genie supply chain management-2ere annee.json
#  → Generating batch 1/1 ...
#  7 pairs added from emploi du temps-genie supply chain management-2ere annee.json
# Progress saved after emploi du temps-genie supply chain management-2ere annee.json
#
# Processing: emploi du temps-genie systeme telecom et reseaux-1ere annee.json
#  → Generating batch 1/1 ...
#  8 pairs added from emploi du temps-genie systeme telecom et reseaux-1ere annee.json
# Progress saved after emploi du temps-genie systeme telecom et reseaux-1ere annee.json
#
# Processing: emploi du temps-genie systeme telecom et reseaux-2ere annee.json
#  → Generating batch 1/1 ...
#  8 pairs added from emploi du temps-genie systeme telecom et reseaux-2ere annee.json
# Progress saved after emploi du temps-genie systeme telecom et reseaux-2ere annee.json
#
# Processing: formation-annees-preparatoires.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-annees-preparatoires.txt
# Progress saved after formation-annees-preparatoires.txt
#
# Processing: formation-continue-3.txt
#  → Generating batch 1/1 ...
#  9 pairs added from formation-continue-3.txt
# Progress saved after formation-continue-3.txt
#
# Processing: formation-genie-civil.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-genie-civil.txt
# Progress saved after formation-genie-civil.txt
#
# Processing: formation-genie-des-systemes-de-telecommunications-et-reseaux.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-genie-des-systemes-de-telecommunications-et-reseaux.txt
# Progress saved after formation-genie-des-systemes-de-telecommunications-et-reseaux.txt
#
# Processing: formation-genie-en-cybersecurite-et-systemes-embarques.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-genie-en-cybersecurite-et-systemes-embarques.txt
# Progress saved after formation-genie-en-cybersecurite-et-systemes-embarques.txt
#
# Processing: formation-genie-informatique.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-genie-informatique.txt
# Progress saved after formation-genie-informatique.txt
#
# Processing: formation-genie-mecatronique.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-genie-mecatronique.txt
# Progress saved after formation-genie-mecatronique.txt
#
# Processing: formation-master-ts2a.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-master-ts2a.txt
# Progress saved after formation-master-ts2a.txt
#
# Processing: formation-science-des-donnees-big-data-intelligence-artificielle.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-science-des-donnees-big-data-intelligence-artificielle.txt
# Progress saved after formation-science-des-donnees-big-data-intelligence-artificielle.txt
#
# Processing: formation-supply-chain-management.txt
#  → Generating batch 1/1 ...
#  7 pairs added from formation-supply-chain-management.txt
# Progress saved after formation-supply-chain-management.txt
#
# Processing: labo-Mathematics computer science and decision making.txt
#  → Generating batch 1/1 ...
#  8 pairs added from labo-Mathematics computer science and decision making.txt
# Progress saved after labo-Mathematics computer science and decision making.txt
#
# Processing: laboratoire-Ingénierie des Systèmes Innovants.txt
#  → Generating batch 1/1 ...
#  8 pairs added from laboratoire-Ingénierie des Systèmes Innovants.txt
# Progress saved after laboratoire-Ingénierie des Systèmes Innovants.txt
#
# Processing: laboratoire-Sciences et Technologies Industrielles et Civiles.txt
#  → Generating batch 1/1 ...
#  7 pairs added from laboratoire-Sciences et Technologies Industrielles et Civiles.txt
# Progress saved after laboratoire-Sciences et Technologies Industrielles et Civiles.txt
#
# Processing: laboratoire-Système d’Information et Génie Logiciel.txt
#  → Generating batch 1/1 ...
#  7 pairs added from laboratoire-Système d’Information et Génie Logiciel.txt
# Progress saved after laboratoire-Système d’Information et Génie Logiciel.txt
#
# Processing: Présentation de Ecole.txt
#  → Generating batch 1/2 ...
#  → Generating batch 2/2 ...
#  14 pairs added from Présentation de Ecole.txt
# Progress saved after Présentation de Ecole.txt
#
# Processing: Conventions et partenariats.txt
#  → Generating batch 1/1 ...
#  7 pairs added from Conventions et partenariats.txt
# Progress saved after Conventions et partenariats.txt
#
# Processing: Manifestations Scientifiques.txt
#  → Generating batch 1/1 ...
#  7 pairs added from Manifestations Scientifiques.txt
# Progress saved after Manifestations Scientifiques.txt
#
# Processing: projets de Recheche.txt
#  → Generating batch 1/1 ...
#  7 pairs added from projets de Recheche.txt
# Progress saved after projets de Recheche.txt
#
# Processing: Équipe de Recherche Télédétection, Systèmes et Télécommunications.txt
#  → Generating batch 1/1 ...
#  7 pairs added from Équipe de Recherche Télédétection, Systèmes et Télécommunications.txt
# Progress saved after Équipe de Recherche Télédétection, Systèmes et Télécommunications.txt
